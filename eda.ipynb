# %% [markdown]
# ### Analyticon 2023 EDA
# #### Author: Jie Chen (jiematth@)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('pokedex_(Update_05.20).csv',index_col=False)
print(df.shape)
# Out:
# (1028, 51)

# %%
df.head(n=50)
# Out:
#     Unnamed: 0  pokedex_number              name german_name  \
# 0            0               1         Bulbasaur     Bisasam
# 1            1               2           Ivysaur   Bisaknosp
# 2            2               3          Venusaur    Bisaflor
# 3            3               3     Mega Venusaur    Bisaflor
# 4            4               4        Charmander    Glumanda
# 5            5               5        Charmeleon     Glutexo
# 6            6               6         Charizard      Glurak
# 7            7               6  Mega Charizard X      Glurak
# 8            8               6  Mega Charizard Y      Glurak
# 9            9               7          Squirtle     Schiggy
# 10          10               8         Wartortle    Schillok
# 11          11               9         Blastoise      Turtok
# 12          12               9    Mega Blastoise      Turtok
# 13          13              10          Caterpie       Raupy
# ...

# %%
df[df.name=='Nidorina']
# Out:
#     Unnamed: 0  pokedex_number      name german_name     japanese_name  \
# 41          41              30  Nidorina    Nidorina  ニドリーナ (Nidorina)
#
#     generation  status             species  type_number  type_1 type_2  \
# 41           1  Normal  Poison Pin Pokémon            1  Poison    NaN
#
#     height_m  weight_kg  abilities_number     ability_1 ability_2  \
# 41       0.8       20.0                 3  Poison Point   Rivalry
#
#    ability_hidden  total_points    hp  attack  defense  sp_attack  sp_defense  \
# 41         Hustle         365.0  70.0    62.0     67.0       55.0        55.0
#
#     speed  catch_rate  base_friendship  base_experience  growth_rate  \
# 41   56.0       120.0             70.0            128.0  Medium Slow
#
#     egg_type_number    egg_type_1 egg_type_2  percentage_male  egg_cycles  \
# 41                1  Undiscovered        NaN              0.0        20.0
#
#     against_normal  against_fire  against_water  against_electric  \
# ...

# %%
df[df.pokedex_number>25].head(n=10)
# Out:
#     Unnamed: 0  pokedex_number              name german_name  \
# 34          34              26            Raichu      Raichu
# 35          35              26     Alolan Raichu      Raichu
# 36          36              27         Sandshrew      Sandan
# 37          37              27  Alolan Sandshrew      Sandan
# 38          38              28         Sandslash    Sandamer
# 39          39              28  Alolan Sandslash    Sandamer
# 40          40              29          Nidoran♀    Nidoran♀
# 41          41              30          Nidorina    Nidorina
# 42          42              31         Nidoqueen   Nidoqueen
# 43          43              32          Nidoran♂    Nidoran♂
#
#         japanese_name  generation  status             species  type_number  \
# 34     ライチュウ (Raichu)           1  Normal       Mouse Pokémon            1
# 35     ライチュウ (Raichu)           1  Normal       Mouse Pokémon            2
# ...

# %%
df[df.name=='Mr. Mime']
# Out:
#      Unnamed: 0  pokedex_number      name german_name     japanese_name  \
# 155         155             122  Mr. Mime    Pantimos  バリヤード (Barrierd)
#
#      generation  status          species  type_number   type_1 type_2  \
# 155           1  Normal  Barrier Pokémon            2  Psychic  Fairy
#
#      height_m  weight_kg  abilities_number   ability_1 ability_2  \
# 155       1.3       54.5                 3  Soundproof    Filter
#
#     ability_hidden  total_points    hp  attack  defense  sp_attack  \
# 155     Technician         460.0  40.0    45.0     65.0      100.0
#
#      sp_defense  speed  catch_rate  base_friendship  base_experience  \
# 155       120.0   90.0        45.0             70.0            161.0
#
#      growth_rate  egg_type_number  egg_type_1 egg_type_2  percentage_male  \
# 155  Medium Fast                1  Human-Like        NaN             50.0
#
#      egg_cycles  against_normal  against_fire  against_water  \
# ...

# %%
sub_df = df[df.name=='Alolan Vulpix']
sub_df.abilities_number.unique()[0]==2
# Out:
# True

# %%
for i in df.columns:
    print(i,len(df[[i]].value_counts()))
    if len(df[[i]].value_counts())<=10:
        print(df[[i]].value_counts())
# Out:
# Unnamed: 0 1028
# pokedex_number 890
# name 1028
# german_name 807
# japanese_name 807
# generation 8
# generation
# 1             192
# 5             171
# 3             165
# 4             121
# 2             107
# 7              99
# 8              88
# 6              85
# dtype: int64
# status 4
# status
# Normal           915
# Sub Legendary     45
# Legendary         39
# Mythical          29
# dtype: int64
# species 641
# type_number 2
# type_number
# 2              542
# 1              486
# dtype: int64
# type_1 18
# type_2 18
# height_m 61
# weight_kg 468
# abilities_number 4
# abilities_number
# 3                   511
# 2                   299
# 1                   217
# 0                     1
# dtype: int64
# ability_1 202
# ability_2 126
# ability_hidden 154
# total_points 216
# hp 102
# attack 123
# defense 114
# sp_attack 119
# sp_defense 107
# speed 126
# catch_rate 34
# base_friendship 6
# base_friendship
# 70.0               747
# 35.0                81
# ...

# %%
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import numpy as np
import requests
import json
from IPython.core.display import Image, display
from IPython.display import Image, Markdown
import random
generations = [151, 252, 802]
pokemon_number = random.randint(1, generations[1])

pokemon_url = 'http://pokeapi.co/api/v2/pokemon/{}/'.format(pokemon_number)
response_json = requests.get(pokemon_url).json()

pokemon_name = response_json['name'].title()
sprites = response_json['sprites']
sprite_url = sprites['front_default']

display(Markdown("#### A wild {} appeared!".format(pokemon_name)))
display(Image(sprite_url))
# Out:
# /var/folders/8z/r61427k57g735tst22bg5k_53z0r4h/T/ipykernel_27835/2280776963.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import Image, display
# #### A wild Hoothoot appeared!

# %%
url = 'https://pokeapi.co/api/v2/pokemon/nidoran-f'
response = requests.get(url)
pokemon_data=response.json()
image_url = pokemon_data['sprites']['front_default']

# %%
image_url
# Out:
# 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/29.png'

# %%
#ability_df = df.loc[df.name=='Celebi', df.columns.str.startswith('against')]

# %%
plot_df = df.loc[df.name=='Celebi',['hp','attack','defense','speed','sp_attack','sp_defense']]
plot_df.columns = ['HP','Attack','Defense','Speed','Sp. Attack','Sp. Defense']

# %%
plot_df2 = plot_df.transpose().reset_index(drop=False)

# %%
plot_df2.columns=['type','points']

# %%
#pip install --upgrade nbformat

# %%
import plotly.express as px
px.line_polar(plot_df2, 
              r='points', 
              theta='type', line_close=True, 
              range_r=(0,100),
              title='Pokemon Attributes',
              template = 'seaborn'
             )
# Out:
# /Users/jiematth/Documents/Analytion2023/.venv/lib/python3.9/site-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
